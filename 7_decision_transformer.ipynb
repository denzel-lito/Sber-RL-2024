# %% [markdown]
# # Decision Transformer
#
# Adapted from [original](https://github.com/kzl/decision-transformer) and [minimalistic](https://github.com/nikhilbarhate99/min-decision-transformer/tree/master) implementations.

# %% [markdown]
# # Устанавливаем зависимости

# %%
# !apt-get install -y \
    libgl1-mesa-dev \
    libgl1-mesa-glx \
    libglew-dev \
    libosmesa6-dev \
    software-properties-common

# !apt-get install -y patchelf
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libglew-dev is already the newest version (2.2.0-4).
# libgl1-mesa-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# libosmesa6-dev is already the newest version (23.2.1-1ubuntu3.1~22.04.2).
# software-properties-common is already the newest version (0.99.22.9).
# libgl1-mesa-glx is already the newest version (23.0.4-0ubuntu1~22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# patchelf is already the newest version (0.14.3-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.

# %%
# !pip install mujoco_py==2.0.2.8
# Out:
# Collecting mujoco_py==2.0.2.8
#   Downloading mujoco_py-2.0.2.8-py3-none-any.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 14.0 MB/s eta 0:00:00
# Collecting glfw>=1.4.0 (from mujoco_py==2.0.2.8)
#   Downloading glfw-2.7.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (211 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.11 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.25.2)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (3.0.10)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py==2.0.2.8) (1.16.0)
# Collecting fasteners~=0.15 (from mujoco_py==2.0.2.8)
#   Downloading fasteners-0.19-py3-none-any.whl (18 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py==2.0.2.8) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py==2.0.2.8) (9.4.0)

# %%
# !pip install gym==0.23
# Out:
# Collecting gym==0.23
#   Downloading gym-0.23.0.tar.gz (624 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 624.4/624.4 kB 10.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.23) (1.25.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym==0.23) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym==0.23) (0.0.8)
# Building wheels for collected packages: gym
#   Building wheel for gym (pyproject.toml) ... done
#   Created wheel for gym: filename=gym-0.23.0-py3-none-any.whl size=697632 sha256=3248081e881157ee4448ddc0d03fc85a78c23491c9989ea3037d78bd0373dbae
#   Stored in directory: /root/.cache/pip/wheels/3d/6f/b4/3991d4fae11d0ecb0754c11cc1b4e7745012850da4efaaf0b1
# Successfully built gym
# Installing collected packages: gym
#   Attempting uninstall: gym
#     Found existing installation: gym 0.25.2
#     Uninstalling gym-0.25.2:
#       Successfully uninstalled gym-0.25.2
# Successfully installed gym-0.23.0

# %%
# !pip install free-mujoco-py
# Out:
# Collecting free-mujoco-py
#   Downloading free_mujoco_py-2.1.6-py3-none-any.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 40.9 MB/s eta 0:00:00
# Collecting Cython<0.30.0,>=0.29.24 (from free-mujoco-py)
#   Downloading Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 58.5 MB/s eta 0:00:00
# Requirement already satisfied: cffi<2.0.0,>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from free-mujoco-py) (1.16.0)
# Collecting fasteners==0.15 (from free-mujoco-py)
#   Downloading fasteners-0.15-py2.py3-none-any.whl (23 kB)
# Collecting glfw<2.0.0,>=1.4.0 (from free-mujoco-py)
#   Downloading glfw-1.12.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38-none-manylinux2014_x86_64.whl (203 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio<3.0.0,>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from free-mujoco-py) (2.31.6)
# Requirement already satisfied: numpy<2.0.0,>=1.21.3 in /usr/local/lib/python3.10/dist-packages (from free-mujoco-py) (1.25.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fasteners==0.15->free-mujoco-py) (1.16.0)
# Collecting monotonic>=0.1 (from fasteners==0.15->free-mujoco-py)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi<2.0.0,>=1.15.0->free-mujoco-py) (2.22)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0.0,>=2.9.0->free-mujoco-py) (9.4.0)
# Installing collected packages: monotonic, glfw, fasteners, Cython, free-mujoco-py
#   Attempting uninstall: glfw
#     Found existing installation: glfw 2.7.0
#     Uninstalling glfw-2.7.0:
#       Successfully uninstalled glfw-2.7.0
#   Attempting uninstall: fasteners
#     Found existing installation: fasteners 0.19
#     Uninstalling fasteners-0.19:
#       Successfully uninstalled fasteners-0.19
#   Attempting uninstall: Cython
#     Found existing installation: Cython 3.0.10
#     Uninstalling Cython-3.0.10:
#       Successfully uninstalled Cython-3.0.10
# Successfully installed Cython-0.29.37 fasteners-0.15 free-mujoco-py-2.1.6 glfw-1.12.0 monotonic-1.6

# %%
# !pip install git+https://github.com/Farama-Foundation/d4rl@master#egg=d4rl
# Out:
# Collecting d4rl
#   Cloning https://github.com/Farama-Foundation/d4rl (to revision master) to /tmp/pip-install-36v285c8/d4rl_b57bd64dedf5433db77ea36c21bd99c7
#   Running command git clone --filter=blob:none --quiet https://github.com/Farama-Foundation/d4rl /tmp/pip-install-36v285c8/d4rl_b57bd64dedf5433db77ea36c21bd99c7
#   Resolved https://github.com/Farama-Foundation/d4rl to commit 71a9549f2091accff93eeff68f1f3ab2c0e0a288
#   Preparing metadata (setup.py) ... done
# Collecting mjrl@ git+https://github.com/aravindr93/mjrl@master#egg=mjrl (from d4rl)
#   Cloning https://github.com/aravindr93/mjrl (to revision master) to /tmp/pip-install-36v285c8/mjrl_466fb268d56544ce938fee8e66da029c
#   Running command git clone --filter=blob:none --quiet https://github.com/aravindr93/mjrl /tmp/pip-install-36v285c8/mjrl_466fb268d56544ce938fee8e66da029c
#   Resolved https://github.com/aravindr93/mjrl to commit 3871d93763d3b49c4741e6daeaebbc605fe140dc
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gym<0.24.0 in /usr/local/lib/python3.10/dist-packages (from d4rl) (0.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from d4rl) (1.25.2)
# Requirement already satisfied: mujoco_py in /usr/local/lib/python3.10/dist-packages (from d4rl) (2.0.2.8)
# Collecting pybullet (from d4rl)
#   Downloading pybullet-3.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (103.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 MB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from d4rl) (3.9.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from d4rl) (2.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from d4rl) (8.1.7)
# Collecting dm_control>=1.0.3 (from d4rl)
#   Downloading dm_control-1.0.17-py3-none-any.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (1.4.0)
# Collecting dm-env (from dm_control>=1.0.3->d4rl)
#   Downloading dm_env-1.6-py3-none-any.whl (26 kB)
# Requirement already satisfied: dm-tree!=0.1.2 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (0.1.8)
# Requirement already satisfied: glfw in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (1.12.0)
# Collecting labmaze (from dm_control>=1.0.3->d4rl)
#   Downloading labmaze-1.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 80.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (4.9.4)
# Collecting mujoco>=3.1.3 (from dm_control>=1.0.3->d4rl)
#   Downloading mujoco-3.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 86.4 MB/s eta 0:00:00
# Requirement already satisfied: protobuf>=3.19.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (3.20.3)
# Requirement already satisfied: pyopengl>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (3.1.7)
# Requirement already satisfied: pyparsing>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (3.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (2.31.0)
# Requirement already satisfied: setuptools!=50.0.0 in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (67.7.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (1.11.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from dm_control>=1.0.3->d4rl) (4.66.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->d4rl) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym<0.24.0->d4rl) (0.0.8)
# Requirement already satisfied: Cython>=0.27.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->d4rl) (0.29.37)
# Requirement already satisfied: imageio>=2.1.2 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->d4rl) (2.31.6)
# Requirement already satisfied: cffi>=1.10 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->d4rl) (1.16.0)
# Requirement already satisfied: fasteners~=0.15 in /usr/local/lib/python3.10/dist-packages (from mujoco_py->d4rl) (0.15)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.10->mujoco_py->d4rl) (2.22)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fasteners~=0.15->mujoco_py->d4rl) (1.16.0)
# Requirement already satisfied: monotonic>=0.1 in /usr/local/lib/python3.10/dist-packages (from fasteners~=0.15->mujoco_py->d4rl) (1.6)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio>=2.1.2->mujoco_py->d4rl) (9.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.10/dist-packages (from mujoco>=3.1.3->dm_control>=1.0.3->d4rl) (1.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->d4rl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->d4rl) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->d4rl) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->dm_control>=1.0.3->d4rl) (2024.2.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.3->dm_control>=1.0.3->d4rl) (2023.6.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.3->dm_control>=1.0.3->d4rl) (6.4.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.3->dm_control>=1.0.3->d4rl) (4.10.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[epath]->mujoco>=3.1.3->dm_control>=1.0.3->d4rl) (3.18.1)
# Building wheels for collected packages: d4rl, mjrl
#   Building wheel for d4rl (setup.py) ... done
#   Created wheel for d4rl: filename=D4RL-1.1-py3-none-any.whl size=26412940 sha256=4393dfc163fd415d8ac8e6da4b207dd0520b54c4a4e77ac02cf6c1c5e90936a8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mkkxov1i/wheels/7a/6e/e1/e5d8e3f6d89271fbc022dc955bb64360665044214be4e17251
#   Building wheel for mjrl (setup.py) ... done
#   Created wheel for mjrl: filename=mjrl-1.0.0-py3-none-any.whl size=61936 sha256=aaec3f06d3e03b31dcddb664bb0bc2fcbaaa9eeb780e720b9205f9f679b15499
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mkkxov1i/wheels/8f/99/f9/efd223b38d503df5eaada10ffe96a869fb0c0f3c92d9e43ed0
# Successfully built d4rl mjrl
# Installing collected packages: pybullet, mjrl, labmaze, dm-env, mujoco, dm_control, d4rl
# Successfully installed d4rl-1.1 dm-env-1.6 dm_control-1.0.17 labmaze-1.0.6 mjrl-1.0.0 mujoco-3.1.3 pybullet-3.2.6

# %% [markdown]
# # Скачиваем данные
#
# Доступные датасеты: [d4rl tasks](https://github.com/Farama-Foundation/d4rl/wiki/Tasks).

# %%
# %env D4RL_SUPPRESS_IMPORT_ERROR=1
import os
import sys
import random
import csv
from datetime import datetime
import pickle
import collections
import math

import gym
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

import d4rl


ENV_NAMES = ['halfcheetah']  # walker2d, halfcheetah, hopper
DATASET_TYPES = ['medium']  # medium, medium-expert, medium-replay


def download_d4rl_data():
    datasets = []

    data_dir = 'data/'
    print(data_dir)

    if not os.path.exists(data_dir):
        os.makedirs(data_dir)

    for env_name in ENV_NAMES:
        for dataset_type in DATASET_TYPES:

            name = f'{env_name}-{dataset_type}-v2'
            pkl_file_path = os.path.join(data_dir, name)

            print("processing: ", name)

            env = gym.make(name)
            dataset = env.get_dataset()

            N = dataset['rewards'].shape[0]
            data_ = collections.defaultdict(list)

            use_timeouts = False
            if 'timeouts' in dataset:
                use_timeouts = True

            episode_step = 0
            paths = []
            for i in range(N):
                done_bool = bool(dataset['terminals'][i])
                if use_timeouts:
                    final_timestep = dataset['timeouts'][i]
                else:
                    final_timestep = (episode_step == 1000-1)
                for k in ['observations', 'next_observations', 'actions', 'rewards', 'terminals']:
                    data_[k].append(dataset[k][i])
                if done_bool or final_timestep:
                    episode_step = 0
                    episode_data = {}
                    for k in data_:
                        episode_data[k] = np.array(data_[k])
                    paths.append(episode_data)
                    data_ = collections.defaultdict(list)
                episode_step += 1

            returns = np.array([np.sum(p['rewards']) for p in paths])
            num_samples = np.sum([p['rewards'].shape[0] for p in paths])
            print(f'Number of samples collected: {num_samples}')
            print(
                f'Trajectory returns: mean = {np.mean(returns)}, std = {np.std(returns)}, max = {np.max(returns)}, min = {np.min(returns)}')

            with open(f'{pkl_file_path}.pkl', 'wb') as f:
                pickle.dump(paths, f)


download_d4rl_data()
# Out:
# env: D4RL_SUPPRESS_IMPORT_ERROR=1
# Compiling /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.pyx because it changed.
# [1/1] Cythonizing /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.pyx
# INFO:root:running build_ext
# INFO:root:building 'mujoco_py.cymj' extension
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/mujoco_py -I/usr/local/lib/python3.10/dist-packages/mujoco_py/binaries/linux/mujoco210/include -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c /usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.c -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.o -fopenmp -w
# INFO:root:x86_64-linux-gnu-gcc -Wno-unused-result -Wsign-compare -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -g -fwrapv -O2 -fPIC -I/usr/local/lib/python3.10/dist-packages/mujoco_py -I/usr/local/lib/python3.10/dist-packages/mujoco_py/binaries/linux/mujoco210/include -I/usr/local/lib/python3.10/dist-packages/numpy/core/include -I/usr/include/python3.10 -c /usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.c -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.o -fopenmp -w
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310
# INFO:root:creating /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310/mujoco_py
# INFO:root:x86_64-linux-gnu-gcc -shared -Wl,-O1 -Wl,-Bsymbolic-functions -Wl,-Bsymbolic-functions -g -fwrapv -O2 /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/cymj.o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/temp.linux-x86_64-cpython-310/usr/local/lib/python3.10/dist-packages/mujoco_py/gl/osmesashim.o -L/usr/local/lib/python3.10/dist-packages/mujoco_py/binaries/linux/mujoco210/bin -L/usr/lib/x86_64-linux-gnu -Wl,--enable-new-dtags,-R/usr/local/lib/python3.10/dist-packages/mujoco_py/binaries/linux/mujoco210/bin -lmujoco210 -lglewosmesa -lOSMesa -lGL -o /usr/local/lib/python3.10/dist-packages/mujoco_py/generated/_pyxbld_2.0.2.13_310_linuxcpuextensionbuilder/lib.linux-x86_64-cpython-310/mujoco_py/cymj.cpython-310-x86_64-linux-gnu.so -fopenmp
# INFO:absl:MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# INFO:absl:Failed to import OpenGL backend: glfw
# INFO:OpenGL.acceleratesupport:No OpenGL_accelerate module loaded: No module named 'OpenGL_accelerate'
# INFO:absl:Successfully imported OpenGL backend: egl
# INFO:absl:MuJoCo library version is: 3.1.3
# /usr/local/lib/python3.10/dist-packages/gym/spaces/box.py:84: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# data/
# processing:  halfcheetah-medium-v2
# Downloading dataset: http://rail.eecs.berkeley.edu/datasets/offline_rl/gym_mujoco_v2/halfcheetah_medium-v2.hdf5 to /root/.d4rl/datasets/halfcheetah_medium-v2.hdf5
# load datafile: 100%|██████████| 21/21 [00:03<00:00,  6.90it/s]
# Number of samples collected: 1000000
# Trajectory returns: mean = 4770.3349609375, std = 355.7503967285156, max = 5309.37939453125, min = -310.23419189453125

# %% [markdown]
# # Attention

# %% [markdown]
# Transformer consists of stacked self-attention layers with residual connections. Each self-attention layer receives $n$ embeddings $\{x_i\}_{i=1}^n$ corresponding to unique input tokens, and outputs $n$ embeddings $\{z_i\}_{i=1}^n$, preserving the input dimensions. The $i$-th token is mapped via linear transformations to a key $k_i$, query $q_i$, and value $v_i$. The $i$-th output of the self-attention layer is given by weighting the values $v_j$ by the normalized dot product between the query $q_i$ and other keys $k_j$:
#
# $$z_i = \sum_{j=1}^n \operatorname{softmax}(\{\langle q_i, k_{j'} \rangle\}_{j'=1}^n) \cdot v_j$$
#
# GPT architecture modifies the transformer architecture with a causal self-attention mask to enable autoregressive generation, replacing the summation / softmax over the $n$ tokens with only the previous tokens in the sequence $(j \in [1, i])$.
#
# (from DT [paper](https://arxiv.org/pdf/2106.01345.pdf))

# %% [markdown]
# Scaled dot-product attention from AIAYN [paper](https://arxiv.org/pdf/1706.03762.pdf):
#
# $$\operatorname{Attention}(Q, K, V) = \operatorname{softmax}(\frac{Q K^T}{\sqrt{d_k}}) V,
# $$
#
# where $d_k$ is dimension of queries and keys

# %% [markdown]
# # Multi-Head Attention:

# %%
class MaskedCausalAttention(nn.Module):
    def __init__(self, h_dim, max_T, n_heads, drop_p):
        super().__init__()

        self.n_heads = n_heads
        self.max_T = max_T

        self.q_net = nn.Linear(h_dim, h_dim)
        self.k_net = nn.Linear(h_dim, h_dim)
        self.v_net = nn.Linear(h_dim, h_dim)

        self.proj_net = nn.Linear(h_dim, h_dim)

        self.att_drop = nn.Dropout(drop_p)
        self.proj_drop = nn.Dropout(drop_p)

        ones = torch.ones((max_T, max_T))
        mask = torch.tril(ones).view(1, 1, max_T, max_T)

        # register buffer makes sure mask does not get updated
        # during backpropagation
        self.register_buffer('mask', mask)

    def forward(self, x):
        B, T, C = x.shape # batch size, seq length, h_dim

        N, D = self.n_heads, C // self.n_heads # N = num heads, D = attention dim

        # rearrange q, k, v as (B, N, T, D)
        q = self.q_net(x).view(B, T, N, D).transpose(1,2)
        k = self.k_net(x).view(B, T, N, D).transpose(1,2)
        v = self.v_net(x).view(B, T, N, D).transpose(1,2)

        # weights (B, N, T, T)
        # weights = ...
        ####### Здесь ваш код ########
        weights = q @ k.transpose(2, 3) / math.sqrt(D)
        ##############################

        # causal mask applied to weights
        # weights = weights.masked_fill( ... )
        # [1, 0, 0, 0]
        # [1, 1, 0, 0]
        # [1, 1, 1, 0]
        # [1, 1, 1, 1]
        ####### Здесь ваш код ########
        weights = weights.masked_fill(self.mask[..., :T, :T] == 0, float('-inf'))
        ##############################

        # normalize weights, all -inf -> 0 after softmax
        # normalized_weights = ...
        ####### Здесь ваш код ########
        normalized_weights = F.softmax(weights, dim=-1)
        ##############################

        # attention (B, N, T, D)
        # attention = self.att_drop( ... )
        ####### Здесь ваш код ########
        attention = self.att_drop(normalized_weights @ v)
        ##############################

        # gather heads and project (B, N, T, D) -> (B, T, N*D)
        attention = attention.transpose(1, 2).contiguous().view(B,T,N*D)

        out = self.proj_drop(self.proj_net(attention))
        return out

# %%
class Block(nn.Module):
    def __init__(self, h_dim, max_T, n_heads, drop_p):
        super().__init__()
        self.attention = MaskedCausalAttention(h_dim, max_T, n_heads, drop_p)
        self.mlp = nn.Sequential(
                nn.Linear(h_dim, 4*h_dim),
                nn.GELU(),
                nn.Linear(4*h_dim, h_dim),
                nn.Dropout(drop_p),
            )
        self.ln1 = nn.LayerNorm(h_dim)
        self.ln2 = nn.LayerNorm(h_dim)

    def forward(self, x):
        # Attention -> LayerNorm -> MLP -> LayerNorm
        ####### Здесь ваш код ########
        x = self.attention(x) + x
        x = self.ln1(x)
        x = self.mlp(x) + x
        x = self.ln2(x)
        ##############################
        return x


class DecisionTransformer(nn.Module):
    def __init__(self, state_dim, act_dim, n_blocks, h_dim, context_len,
                 n_heads, drop_p, max_timestep=4096):
        super().__init__()

        self.state_dim = state_dim
        self.act_dim = act_dim
        self.h_dim = h_dim

        ### transformer blocks
        input_seq_len = 3 * context_len
        blocks = [Block(h_dim, input_seq_len, n_heads, drop_p) for _ in range(n_blocks)]
        self.transformer = nn.Sequential(*blocks)

        ### projection heads (project to embedding)
        self.embed_ln = nn.LayerNorm(h_dim)
        self.embed_timestep = nn.Embedding(max_timestep, h_dim)
        self.embed_rtg = torch.nn.Linear(1, h_dim)
        self.embed_state = torch.nn.Linear(state_dim, h_dim)

        # # discrete actions
        # self.embed_action = torch.nn.Embedding(act_dim, h_dim)
        # use_action_tanh = False # False for discrete actions

        # continuous actions
        self.embed_action = torch.nn.Linear(act_dim, h_dim)
        use_action_tanh = True # True for continuous actions

        ### prediction heads
        self.predict_rtg = torch.nn.Linear(h_dim, 1)
        self.predict_state = torch.nn.Linear(h_dim, state_dim)
        self.predict_action = nn.Sequential(
            *([nn.Linear(h_dim, act_dim)] + ([nn.Tanh()] if use_action_tanh else []))
        )


    def forward(self, timesteps, states, actions, returns_to_go):

        B, T, _ = states.shape

        time_embeddings = self.embed_timestep(timesteps)

        # time embeddings are treated similar to positional embeddings
        state_embeddings = self.embed_state(states) + time_embeddings
        action_embeddings = self.embed_action(actions) + time_embeddings
        returns_embeddings = self.embed_rtg(returns_to_go) + time_embeddings

        # stack rtg, states and actions and reshape sequence as
        # (r1, s1, a1, r2, s2, a2 ...)
        h = torch.stack(
            (returns_embeddings, state_embeddings, action_embeddings), dim=1
        ).permute(0, 2, 1, 3).reshape(B, 3 * T, self.h_dim)

        h = self.embed_ln(h)

        # transformer and prediction
        # h = ...
        ####### Здесь ваш код ########
        h = self.transformer(h)
        ##############################
        # (B, 3T, h_dim)
        # get h reshaped such that its size = (B x 3 x T x h_dim) and
        # h[:, 0, t] is conditioned on r_0, s_0, a_0 ... r_t
        # h[:, 1, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t
        # h[:, 2, t] is conditioned on r_0, s_0, a_0 ... r_t, s_t, a_t
        h = h.reshape(B, T, 3, self.h_dim).permute(0, 2, 1, 3)

        # get predictions
        return_preds = self.predict_rtg(h[:,2])     # predict next rtg given r, s, a
        state_preds = self.predict_state(h[:,2])    # predict next state given r, s, a
        action_preds = self.predict_action(h[:,1])  # predict action given r, s

        return state_preds, action_preds, return_preds

# %% [markdown]
# # Info

# %%
REF_MAX_SCORE = {
    'halfcheetah' : 12135.0,
    'walker2d' : 4592.3,
    'hopper' : 3234.3,
}

REF_MIN_SCORE = {
    'halfcheetah' : -280.178953,
    'walker2d' : 1.629008,
    'hopper' : -20.272305,
}


## calculated from d4rl datasets

D4RL_DATASET_STATS = {
        'halfcheetah-medium-v2': {
                'state_mean':[-0.06845773756504059, 0.016414547339081764, -0.18354906141757965,
                              -0.2762460708618164, -0.34061527252197266, -0.09339715540409088,
                              -0.21321271359920502, -0.0877423882484436, 5.173007488250732,
                              -0.04275195300579071, -0.036108363419771194, 0.14053793251514435,
                              0.060498327016830444, 0.09550975263118744, 0.06739100068807602,
                              0.005627387668937445, 0.013382787816226482
                ],
                'state_std':[0.07472999393939972, 0.3023499846458435, 0.30207309126853943,
                             0.34417077898979187, 0.17619241774082184, 0.507205605506897,
                             0.2567007839679718, 0.3294812738895416, 1.2574149370193481,
                             0.7600541710853577, 1.9800915718078613, 6.565362453460693,
                             7.466367721557617, 4.472222805023193, 10.566964149475098,
                             5.671932697296143, 7.4982590675354
                ]
            },
        'halfcheetah-medium-replay-v2': {
                'state_mean':[-0.12880703806877136, 0.3738119602203369, -0.14995987713336945,
                              -0.23479078710079193, -0.2841278612613678, -0.13096535205841064,
                              -0.20157982409000397, -0.06517726927995682, 3.4768247604370117,
                              -0.02785065770149231, -0.015035249292850494, 0.07697279006242752,
                              0.01266712136566639, 0.027325302362442017, 0.02316424623131752,
                              0.010438721626996994, -0.015839405357837677
                ],
                'state_std':[0.17019015550613403, 1.284424901008606, 0.33442774415016174,
                             0.3672759234905243, 0.26092398166656494, 0.4784106910228729,
                             0.3181420564651489, 0.33552637696266174, 2.0931615829467773,
                             0.8037433624267578, 1.9044333696365356, 6.573209762573242,
                             7.572863578796387, 5.069749355316162, 9.10555362701416,
                             6.085654258728027, 7.25300407409668
                ]
            },
        'halfcheetah-medium-expert-v2': {
                'state_mean':[-0.05667462572455406, 0.024369969964027405, -0.061670560389757156,
                              -0.22351515293121338, -0.2675151228904724, -0.07545716315507889,
                              -0.05809682980179787, -0.027675075456500053, 8.110626220703125,
                              -0.06136331334710121, -0.17986927926540375, 0.25175222754478455,
                              0.24186332523822784, 0.2519369423389435, 0.5879552960395813,
                              -0.24090635776519775, -0.030184272676706314
                ],
                'state_std':[0.06103534251451492, 0.36054104566574097, 0.45544400811195374,
                             0.38476887345314026, 0.2218363732099533, 0.5667523741722107,
                             0.3196682929992676, 0.2852923572063446, 3.443821907043457,
                             0.6728139519691467, 1.8616976737976074, 9.575807571411133,
                             10.029894828796387, 5.903450012207031, 12.128185272216797,
                             6.4811787605285645, 6.378620147705078
                ]
            },
        'walker2d-medium-v2': {
                'state_mean':[1.218966007232666, 0.14163373410701752, -0.03704913705587387,
                              -0.13814310729503632, 0.5138224363327026, -0.04719110205769539,
                              -0.47288352251052856, 0.042254164814949036, 2.3948874473571777,
                              -0.03143199160695076, 0.04466355964541435, -0.023907244205474854,
                              -0.1013401448726654, 0.09090937674045563, -0.004192637279629707,
                              -0.12120571732521057, -0.5497063994407654
                ],
                'state_std':[0.12311358004808426, 0.3241879940032959, 0.11456084251403809,
                             0.2623065710067749, 0.5640279054641724, 0.2271878570318222,
                             0.3837319612503052, 0.7373676896095276, 1.2387926578521729,
                             0.798020601272583, 1.5664079189300537, 1.8092705011367798,
                             3.025604248046875, 4.062486171722412, 1.4586567878723145,
                             3.7445690631866455, 5.5851287841796875
                ]
            },
        'walker2d-medium-replay-v2': {
                'state_mean':[1.209364652633667, 0.13264022767543793, -0.14371201395988464,
                              -0.2046516090631485, 0.5577612519264221, -0.03231537342071533,
                              -0.2784661054611206, 0.19130706787109375, 1.4701707363128662,
                              -0.12504704296588898, 0.0564953051507473, -0.09991033375263214,
                              -0.340340256690979, 0.03546293452382088, -0.08934258669614792,
                              -0.2992438077926636, -0.5984178185462952
                ],
                'state_std':[0.11929835379123688, 0.3562574088573456, 0.25852200388908386,
                             0.42075422406196594, 0.5202291011810303, 0.15685082972049713,
                             0.36770978569984436, 0.7161387801170349, 1.3763766288757324,
                             0.8632221817970276, 2.6364643573760986, 3.0134117603302,
                             3.720684051513672, 4.867283821105957, 2.6681625843048096,
                             3.845186948776245, 5.4768385887146
                ]
            },
        'walker2d-medium-expert-v2': {
                'state_mean':[1.2294334173202515, 0.16869689524173737, -0.07089081406593323,
                              -0.16197483241558075, 0.37101927399635315, -0.012209027074277401,
                              -0.42461398243904114, 0.18986578285694122, 3.162475109100342,
                              -0.018092676997184753, 0.03496946766972542, -0.013921679928898811,
                              -0.05937029421329498, -0.19549426436424255, -0.0019200450042262673,
                              -0.062483321875333786, -0.27366524934768677
                ],
                'state_std':[0.09932824969291687, 0.25981399416923523, 0.15062759816646576,
                             0.24249176681041718, 0.6758718490600586, 0.1650741547346115,
                             0.38140663504600525, 0.6962361335754395, 1.3501490354537964,
                             0.7641991376876831, 1.534574270248413, 2.1785972118377686,
                             3.276582717895508, 4.766193866729736, 1.1716983318328857,
                             4.039782524108887, 5.891613960266113
                ]
            },
        'hopper-medium-v2': {
                'state_mean':[1.311279058456421, -0.08469521254301071, -0.5382719039916992,
                              -0.07201576232910156, 0.04932365566492081, 2.1066856384277344,
                              -0.15017354488372803, 0.008783451281487942, -0.2848185896873474,
                              -0.18540096282958984, -0.28461286425590515
                ],
                'state_std':[0.17790751159191132, 0.05444620922207832, 0.21297138929367065,
                             0.14530418813228607, 0.6124444007873535, 0.8517446517944336,
                             1.4515252113342285, 0.6751695871353149, 1.5362390279769897,
                             1.616074562072754, 5.607253551483154
                ]
            },
        'hopper-medium-replay-v2': {
                'state_mean':[1.2305138111114502, -0.04371410980820656, -0.44542956352233887,
                              -0.09370097517967224, 0.09094487875699997, 1.3694725036621094,
                              -0.19992674887180328, -0.022861352190375328, -0.5287045240402222,
                              -0.14465883374214172, -0.19652697443962097
                ],
                'state_std':[0.1756512075662613, 0.0636928603053093, 0.3438323438167572,
                             0.19566889107227325, 0.5547984838485718, 1.051029920578003,
                             1.158307671546936, 0.7963128685951233, 1.4802359342575073,
                             1.6540331840515137, 5.108601093292236
                ]
            },
        'hopper-medium-expert-v2': {
                'state_mean':[1.3293815851211548, -0.09836531430482864, -0.5444297790527344,
                              -0.10201650857925415, 0.02277466468513012, 2.3577215671539307,
                              -0.06349576264619827, -0.00374026270583272, -0.1766270101070404,
                              -0.11862941086292267, -0.12097819894552231
                ],
                'state_std':[0.17012375593185425, 0.05159067362546921, 0.18141433596611023,
                             0.16430604457855225, 0.6023368239402771, 0.7737284898757935,
                             1.4986555576324463, 0.7483318448066711, 1.7953159809112549,
                             2.0530025959014893, 5.725032806396484
                ]
            },
    }

# %% [markdown]
# # Utils

# %%
def discount_cumsum(x, gamma):
    disc_cumsum = np.zeros_like(x)
    disc_cumsum[-1] = x[-1]
    for t in reversed(range(x.shape[0]-1)):
        disc_cumsum[t] = x[t] + gamma * disc_cumsum[t+1]
    return disc_cumsum


def get_d4rl_dataset_stats(env_d4rl_name):
    return D4RL_DATASET_STATS[env_d4rl_name]


def get_d4rl_normalized_score(score, env_name):
    env_key = env_name.split('-')[0].lower()
    assert env_key in REF_MAX_SCORE, f'no reference score for {env_key} env to calculate d4rl score'
    return (score - REF_MIN_SCORE[env_key]) / (REF_MAX_SCORE[env_key] - REF_MIN_SCORE[env_key])


def evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
                    num_eval_ep=10, max_test_ep_len=1000,
                    state_mean=None, state_std=None, render=False):

    eval_batch_size = 1  # required for forward pass

    results = {}
    total_reward = 0
    total_timesteps = 0

    state_dim = env.observation_space.shape[0]
    act_dim = env.action_space.shape[0]

    if state_mean is None:
        state_mean = torch.zeros((state_dim,)).to(device)
    else:
        state_mean = torch.from_numpy(state_mean).to(device)

    if state_std is None:
        state_std = torch.ones((state_dim,)).to(device)
    else:
        state_std = torch.from_numpy(state_std).to(device)

    # same as timesteps used for training the transformer
    # also, crashes if device is passed to arange()
    timesteps = torch.arange(start=0, end=max_test_ep_len, step=1)
    timesteps = timesteps.repeat(eval_batch_size, 1).to(device)

    model.eval()

    with torch.no_grad():

        for _ in range(num_eval_ep):

            # zeros place holders
            actions = torch.zeros((eval_batch_size, max_test_ep_len, act_dim),
                                dtype=torch.float32, device=device)

            states = torch.zeros((eval_batch_size, max_test_ep_len, state_dim),
                                dtype=torch.float32, device=device)

            rewards_to_go = torch.zeros((eval_batch_size, max_test_ep_len, 1),
                                dtype=torch.float32, device=device)

            # init episode
            running_state = env.reset()
            running_reward = 0
            running_rtg = rtg_target / rtg_scale

            for t in range(max_test_ep_len):

                total_timesteps += 1

                # add state in placeholder and normalize
                states[0, t] = torch.from_numpy(running_state).to(device)
                states[0, t] = (states[0, t] - state_mean) / state_std

                # calcualate running rtg and add in placeholder
                running_rtg = running_rtg - (running_reward / rtg_scale)
                rewards_to_go[0, t] = running_rtg

                if t < context_len:
                    _, act_preds, _ = model.forward(timesteps[:,:context_len],
                                                states[:,:context_len],
                                                actions[:,:context_len],
                                                rewards_to_go[:,:context_len])
                    act = act_preds[0, t].detach()
                else:
                    _, act_preds, _ = model.forward(timesteps[:,t-context_len+1:t+1],
                                                states[:,t-context_len+1:t+1],
                                                actions[:,t-context_len+1:t+1],
                                                rewards_to_go[:,t-context_len+1:t+1])
                    act = act_preds[0, -1].detach()


                running_state, running_reward, done, _ = env.step(act.cpu().numpy())

                # add action in placeholder
                actions[0, t] = act

                total_reward += running_reward

                if render:
                    env.render()
                if done:
                    break

    results['eval/avg_reward'] = total_reward / num_eval_ep
    results['eval/avg_ep_len'] = total_timesteps / num_eval_ep

    return results

# %% [markdown]
# # Dataset

# %%
dataset = "medium"       # medium / medium-replay / medium-expert
rtg_scale = 1000                # scale to normalize returns to go

# use v3 env for evaluation because
# DT paper evaluates results on v3 envs

# env_name = 'Walker2d-v3'
# rtg_target = 5000
# env_d4rl_name = f'walker2d-{dataset}-v2'

env_name = 'HalfCheetah-v3'
rtg_target = 6000
env_d4rl_name = f'halfcheetah-{dataset}-v2'

# env_name = 'Hopper-v3'
# rtg_target = 3600
# env_d4rl_name = f'hopper-{dataset}-v2'


max_eval_ep_len = 1000      # max len of one evaluation episode
num_eval_ep = 10            # num of evaluation episodes per iteration

batch_size = 64             # training batch size
lr = 1e-4                   # learning rate
wt_decay = 1e-4             # weight decay
warmup_steps = 10000        # warmup steps for lr scheduler

# total updates = max_train_iters x num_updates_per_iter
max_train_iters = 200
num_updates_per_iter = 100

context_len = 20        # K in decision transformer
n_blocks = 3            # num of transformer blocks
embed_dim = 128         # embedding (hidden) dim of transformer
n_heads = 1             # num of transformer heads
dropout_p = 0.1         # dropout probability



# load data from this file
dataset_path = f'data/{env_d4rl_name}.pkl'

# saves model and csv in this directory
log_dir = "./dt_runs/"


if not os.path.exists(log_dir):
    os.makedirs(log_dir)


# training and evaluation device
device_name = 'cuda'
device = torch.device(device_name)
print("device set to: ", device)
# Out:
# device set to:  cuda

# %%
# load dataset
with open(dataset_path, 'rb') as f:
    trajectories = pickle.load(f)

min_len = 10**4
states = []
for traj in trajectories:
    min_len = min(min_len, traj['observations'].shape[0])
    states.append(traj['observations'])

# used for input normalization
states = np.concatenate(states, axis=0)
state_mean, state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6

print(dataset_path)
print("num of trajectories in dataset: ", len(trajectories))
print("minimum trajectory length in dataset: ", min_len)
print("state mean: ", state_mean.tolist())
print("state std: ", state_std.tolist())


## check if info is correct
print("is state mean info correct: ", state_mean.tolist() == D4RL_DATASET_STATS[env_d4rl_name]['state_mean'])
print("is state std info correct: ", state_std.tolist() == D4RL_DATASET_STATS[env_d4rl_name]['state_std'])


assert state_mean.tolist() == D4RL_DATASET_STATS[env_d4rl_name]['state_mean']
assert state_std.tolist() == D4RL_DATASET_STATS[env_d4rl_name]['state_std']
# Out:
# data/halfcheetah-medium-v2.pkl
# num of trajectories in dataset:  1000
# minimum trajectory length in dataset:  1000
# state mean:  [-0.06845773756504059, 0.016414547339081764, -0.18354906141757965, -0.2762460708618164, -0.34061527252197266, -0.09339715540409088, -0.21321271359920502, -0.0877423882484436, 5.173007488250732, -0.04275195300579071, -0.036108363419771194, 0.14053793251514435, 0.060498327016830444, 0.09550975263118744, 0.06739100068807602, 0.005627387668937445, 0.013382787816226482]
# state std:  [0.07472999393939972, 0.3023499846458435, 0.30207309126853943, 0.34417077898979187, 0.17619241774082184, 0.507205605506897, 0.2567007839679718, 0.3294812738895416, 1.2574149370193481, 0.7600541710853577, 1.9800915718078613, 6.565362453460693, 7.466367721557617, 4.472222805023193, 10.566964149475098, 5.671932697296143, 7.4982590675354]
# is state mean info correct:  True
# is state std info correct:  True

# %%
class D4RLTrajectoryDataset(Dataset):
    def __init__(self, dataset_path, context_len, rtg_scale):

        self.context_len = context_len

        # load dataset
        with open(dataset_path, 'rb') as f:
            self.trajectories = pickle.load(f)

        # calculate min len of traj, state mean and variance
        # and returns_to_go for all traj
        min_len = 10**6
        states = []
        for traj in self.trajectories:
            traj_len = traj['observations'].shape[0]
            min_len = min(min_len, traj_len)
            states.append(traj['observations'])
            # calculate returns to go and rescale them
            traj['returns_to_go'] = discount_cumsum(traj['rewards'], 1.0) / rtg_scale

        # used for input normalization
        states = np.concatenate(states, axis=0)
        self.state_mean, self.state_std = np.mean(states, axis=0), np.std(states, axis=0) + 1e-6

        # normalize states
        for traj in self.trajectories:
            traj['observations'] = (traj['observations'] - self.state_mean) / self.state_std


    def get_state_stats(self):
        return self.state_mean, self.state_std

    def __len__(self):
        return len(self.trajectories)

    def __getitem__(self, idx):
        traj = self.trajectories[idx]
        traj_len = traj['observations'].shape[0]

        if traj_len >= self.context_len:
            # sample random index to slice trajectory
            si = random.randint(0, traj_len - self.context_len)

            states = torch.from_numpy(traj['observations'][si : si + self.context_len])
            actions = torch.from_numpy(traj['actions'][si : si + self.context_len])
            returns_to_go = torch.from_numpy(traj['returns_to_go'][si : si + self.context_len])
            timesteps = torch.arange(start=si, end=si+self.context_len, step=1)

            # all ones since no padding
            traj_mask = torch.ones(self.context_len, dtype=torch.long)

        else:
            padding_len = self.context_len - traj_len

            # padding with zeros
            states = torch.from_numpy(traj['observations'])
            states = torch.cat([states,
                                torch.zeros(([padding_len] + list(states.shape[1:])),
                                dtype=states.dtype)],
                               dim=0)

            actions = torch.from_numpy(traj['actions'])
            actions = torch.cat([actions,
                                torch.zeros(([padding_len] + list(actions.shape[1:])),
                                dtype=actions.dtype)],
                               dim=0)

            returns_to_go = torch.from_numpy(traj['returns_to_go'])
            returns_to_go = torch.cat([returns_to_go,
                                torch.zeros(([padding_len] + list(returns_to_go.shape[1:])),
                                dtype=returns_to_go.dtype)],
                               dim=0)

            timesteps = torch.arange(start=0, end=self.context_len, step=1)

            traj_mask = torch.cat([torch.ones(traj_len, dtype=torch.long),
                                   torch.zeros(padding_len, dtype=torch.long)],
                                  dim=0)

        return  timesteps, states, actions, returns_to_go, traj_mask

# %% [markdown]
# # Train

# %%
start_time = datetime.now().replace(microsecond=0)

start_time_str = start_time.strftime("%y-%m-%d-%H-%M-%S")

prefix = "dt_" + env_d4rl_name

save_model_name =  prefix + "_model_" + start_time_str + ".pt"
save_model_path = os.path.join(log_dir, save_model_name)
save_best_model_path = save_model_path[:-3] + "_best.pt"

log_csv_name = prefix + "_log_" + start_time_str + ".csv"
log_csv_path = os.path.join(log_dir, log_csv_name)


csv_writer = csv.writer(open(log_csv_path, 'a', 1))
csv_header = (["duration", "num_updates", "action_loss",
               "eval_avg_reward", "eval_avg_ep_len", "eval_d4rl_score"])

csv_writer.writerow(csv_header)


print("=" * 60)
print("start time: " + start_time_str)
print("=" * 60)

print("device set to: " + str(device))
print("dataset path: " + dataset_path)
print("model save path: " + save_model_path)
print("log csv save path: " + log_csv_path)


traj_dataset = D4RLTrajectoryDataset(dataset_path, context_len, rtg_scale)

traj_data_loader = DataLoader(traj_dataset,
						batch_size=batch_size,
						shuffle=True,
						pin_memory=True,
						drop_last=True)

data_iter = iter(traj_data_loader)

## get state stats from dataset
state_mean, state_std = traj_dataset.get_state_stats()

env = gym.make(env_name)

state_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]

model = DecisionTransformer(
			state_dim=state_dim,
			act_dim=act_dim,
			n_blocks=n_blocks,
			h_dim=embed_dim,
			context_len=context_len,
			n_heads=n_heads,
			drop_p=dropout_p,
		).to(device)

optimizer = torch.optim.AdamW(
					model.parameters(),
					lr=lr,
					weight_decay=wt_decay
				)

scheduler = torch.optim.lr_scheduler.LambdaLR(
		optimizer,
		lambda steps: min((steps+1)/warmup_steps, 1)
	)

max_d4rl_score = -1.0
total_updates = 0

for i_train_iter in range(max_train_iters):

	log_action_losses = []
	model.train()

	for _ in range(num_updates_per_iter):
		try:
			timesteps, states, actions, returns_to_go, traj_mask = next(data_iter)
		except StopIteration:
			data_iter = iter(traj_data_loader)
			timesteps, states, actions, returns_to_go, traj_mask = next(data_iter)

		timesteps = timesteps.to(device)	# B x T
		states = states.to(device)			# B x T x state_dim
		actions = actions.to(device)		# B x T x act_dim
		returns_to_go = returns_to_go.to(device).unsqueeze(dim=-1) # B x T x 1
		traj_mask = traj_mask.to(device)	# B x T

		action_target = torch.clone(actions).detach().to(device)

		state_preds, action_preds, return_preds = model.forward(
														timesteps=timesteps,
														states=states,
														actions=actions,
														returns_to_go=returns_to_go
													)

		# only consider non padded elements
		action_preds = action_preds.view(-1, act_dim)[traj_mask.view(-1,) > 0]
		action_target = action_target.view(-1, act_dim)[traj_mask.view(-1,) > 0]

		action_loss = F.mse_loss(action_preds, action_target, reduction='mean')

		optimizer.zero_grad()
		action_loss.backward()
		torch.nn.utils.clip_grad_norm_(model.parameters(), 0.25)
		optimizer.step()
		scheduler.step()

		log_action_losses.append(action_loss.detach().cpu().item())

	# evaluate on env
	results = evaluate_on_env(model, device, context_len, env, rtg_target, rtg_scale,
	                        num_eval_ep, max_eval_ep_len, state_mean, state_std,
							)
	eval_avg_reward = results['eval/avg_reward']
	eval_avg_ep_len = results['eval/avg_ep_len']
	eval_d4rl_score = get_d4rl_normalized_score(results['eval/avg_reward'], env_name) * 100

	mean_action_loss = np.mean(log_action_losses)
	time_elapsed = str(datetime.now().replace(microsecond=0) - start_time)

	total_updates += num_updates_per_iter

	log_str = ("=" * 60 + '\n' +
			"time elapsed: " + time_elapsed  + '\n' +
			"num of updates: " + str(total_updates) + '\n' +
			"action loss: " +  format(mean_action_loss, ".5f") + '\n' +
			"eval avg reward: " + format(eval_avg_reward, ".5f") + '\n' +
			"eval avg ep len: " + format(eval_avg_ep_len, ".5f") + '\n' +
			"eval d4rl score: " + format(eval_d4rl_score, ".5f")
			)

	print(log_str)

	log_data = [time_elapsed, total_updates, mean_action_loss,
				eval_avg_reward, eval_avg_ep_len,
				eval_d4rl_score]

	csv_writer.writerow(log_data)

	# save model
	print("max d4rl score: " + format(max_d4rl_score, ".5f"))
	if eval_d4rl_score >= max_d4rl_score:
		print("saving max d4rl score model at: " + save_best_model_path)
		torch.save(model.state_dict(), save_best_model_path)
		max_d4rl_score = eval_d4rl_score

	print("saving current model at: " + save_model_path)
	torch.save(model.state_dict(), save_model_path)


print("=" * 60)
print("finished training!")
print("=" * 60)
end_time = datetime.now().replace(microsecond=0)
time_elapsed = str(end_time - start_time)
end_time_str = end_time.strftime("%y-%m-%d-%H-%M-%S")
print("started training at: " + start_time_str)
print("finished training at: " + end_time_str)
print("total training time: " + time_elapsed)
print("max d4rl score: " + format(max_d4rl_score, ".5f"))
print("saved max d4rl score model at: " + save_best_model_path)
print("saved last updated model at: " + save_model_path)
print("=" * 60)
# Out:
# ============================================================
# start time: 24-04-04-10-52-44
# ============================================================
# device set to: cuda
# dataset path: data/halfcheetah-medium-v2.pkl
# model save path: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# log csv save path: ./dt_runs/dt_halfcheetah-medium-v2_log_24-04-04-10-52-44.csv
# ============================================================
# time elapsed: 0:00:35
# num of updates: 100
# action loss: 0.88276
# eval avg reward: -167.30292
# eval avg ep len: 1000.00000
# eval d4rl score: 0.90918
# max d4rl score: -1.00000
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:01:08
# num of updates: 200
# action loss: 0.82229
# eval avg reward: -92.83667
# eval avg ep len: 1000.00000
# eval d4rl score: 1.50898
# max d4rl score: 0.90918
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:01:41
# num of updates: 300
# action loss: 0.71953
# eval avg reward: -51.22058
# eval avg ep len: 1000.00000
# eval d4rl score: 1.84418
# max d4rl score: 1.50898
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:02:14
# num of updates: 400
# action loss: 0.60016
# eval avg reward: -87.95963
# eval avg ep len: 1000.00000
# eval d4rl score: 1.54826
# max d4rl score: 1.84418
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:02:47
# num of updates: 500
# action loss: 0.49330
# eval avg reward: -144.91693
# eval avg ep len: 1000.00000
# eval d4rl score: 1.08949
# max d4rl score: 1.84418
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:03:19
# num of updates: 600
# action loss: 0.40947
# eval avg reward: -132.79023
# eval avg ep len: 1000.00000
# eval d4rl score: 1.18717
# max d4rl score: 1.84418
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:03:52
# num of updates: 700
# action loss: 0.33824
# eval avg reward: -75.72842
# eval avg ep len: 1000.00000
# eval d4rl score: 1.64678
# max d4rl score: 1.84418
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:04:25
# num of updates: 800
# action loss: 0.29277
# eval avg reward: 51.68363
# eval avg ep len: 1000.00000
# eval d4rl score: 2.67304
# max d4rl score: 1.84418
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:04:58
# num of updates: 900
# action loss: 0.26457
# eval avg reward: 239.37638
# eval avg ep len: 1000.00000
# eval d4rl score: 4.18484
# max d4rl score: 2.67304
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:05:35
# num of updates: 1000
# action loss: 0.24629
# eval avg reward: 321.15738
# eval avg ep len: 1000.00000
# eval d4rl score: 4.84356
# max d4rl score: 4.18484
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:06:08
# num of updates: 1100
# action loss: 0.23662
# eval avg reward: 574.55481
# eval avg ep len: 1000.00000
# eval d4rl score: 6.88459
# max d4rl score: 4.84356
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:06:41
# num of updates: 1200
# action loss: 0.22494
# eval avg reward: 483.66944
# eval avg ep len: 1000.00000
# eval d4rl score: 6.15254
# max d4rl score: 6.88459
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:07:14
# num of updates: 1300
# action loss: 0.21531
# eval avg reward: 412.56544
# eval avg ep len: 1000.00000
# eval d4rl score: 5.57982
# max d4rl score: 6.88459
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:07:46
# num of updates: 1400
# action loss: 0.20702
# eval avg reward: 156.93920
# eval avg ep len: 1000.00000
# eval d4rl score: 3.52084
# max d4rl score: 6.88459
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:08:18
# num of updates: 1500
# action loss: 0.19800
# eval avg reward: 630.88164
# eval avg ep len: 1000.00000
# eval d4rl score: 7.33828
# max d4rl score: 6.88459
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:08:51
# num of updates: 1600
# action loss: 0.18991
# eval avg reward: 115.68167
# eval avg ep len: 1000.00000
# eval d4rl score: 3.18852
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:09:23
# num of updates: 1700
# action loss: 0.18269
# eval avg reward: 286.07983
# eval avg ep len: 1000.00000
# eval d4rl score: 4.56102
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:09:55
# num of updates: 1800
# action loss: 0.17626
# eval avg reward: 96.94245
# eval avg ep len: 1000.00000
# eval d4rl score: 3.03758
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:10:28
# num of updates: 1900
# action loss: 0.16987
# eval avg reward: 206.19223
# eval avg ep len: 1000.00000
# eval d4rl score: 3.91755
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:11:00
# num of updates: 2000
# action loss: 0.16275
# eval avg reward: 272.24840
# eval avg ep len: 1000.00000
# eval d4rl score: 4.44961
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:11:33
# num of updates: 2100
# action loss: 0.15794
# eval avg reward: 292.22341
# eval avg ep len: 1000.00000
# eval d4rl score: 4.61050
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:12:05
# num of updates: 2200
# action loss: 0.15411
# eval avg reward: 413.76785
# eval avg ep len: 1000.00000
# eval d4rl score: 5.58950
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:12:38
# num of updates: 2300
# action loss: 0.14890
# eval avg reward: 282.57027
# eval avg ep len: 1000.00000
# eval d4rl score: 4.53275
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:13:10
# num of updates: 2400
# action loss: 0.14639
# eval avg reward: 459.56995
# eval avg ep len: 1000.00000
# eval d4rl score: 5.95842
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:13:42
# num of updates: 2500
# action loss: 0.14121
# eval avg reward: 172.51878
# eval avg ep len: 1000.00000
# eval d4rl score: 3.64632
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:14:15
# num of updates: 2600
# action loss: 0.13958
# eval avg reward: 283.58749
# eval avg ep len: 1000.00000
# eval d4rl score: 4.54094
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:14:47
# num of updates: 2700
# action loss: 0.13505
# eval avg reward: 422.62740
# eval avg ep len: 1000.00000
# eval d4rl score: 5.66086
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:15:19
# num of updates: 2800
# action loss: 0.13064
# eval avg reward: 174.33812
# eval avg ep len: 1000.00000
# eval d4rl score: 3.66098
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:15:51
# num of updates: 2900
# action loss: 0.12816
# eval avg reward: 261.20778
# eval avg ep len: 1000.00000
# eval d4rl score: 4.36068
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:16:24
# num of updates: 3000
# action loss: 0.12530
# eval avg reward: 55.13446
# eval avg ep len: 1000.00000
# eval d4rl score: 2.70083
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:16:56
# num of updates: 3100
# action loss: 0.12206
# eval avg reward: 447.41325
# eval avg ep len: 1000.00000
# eval d4rl score: 5.86051
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:17:28
# num of updates: 3200
# action loss: 0.12059
# eval avg reward: 188.68455
# eval avg ep len: 1000.00000
# eval d4rl score: 3.77653
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:18:01
# num of updates: 3300
# action loss: 0.11674
# eval avg reward: 248.37006
# eval avg ep len: 1000.00000
# eval d4rl score: 4.25728
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:18:34
# num of updates: 3400
# action loss: 0.11471
# eval avg reward: 467.85002
# eval avg ep len: 1000.00000
# eval d4rl score: 6.02512
# max d4rl score: 7.33828
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:19:06
# num of updates: 3500
# action loss: 0.11253
# eval avg reward: 901.08802
# eval avg ep len: 1000.00000
# eval d4rl score: 9.51470
# max d4rl score: 7.33828
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:19:38
# num of updates: 3600
# action loss: 0.11068
# eval avg reward: 655.47660
# eval avg ep len: 1000.00000
# eval d4rl score: 7.53638
# max d4rl score: 9.51470
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:20:11
# num of updates: 3700
# action loss: 0.10824
# eval avg reward: 704.76088
# eval avg ep len: 1000.00000
# eval d4rl score: 7.93335
# max d4rl score: 9.51470
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:20:43
# num of updates: 3800
# action loss: 0.10529
# eval avg reward: 1996.15066
# eval avg ep len: 1000.00000
# eval d4rl score: 18.33505
# max d4rl score: 9.51470
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:21:15
# num of updates: 3900
# action loss: 0.10320
# eval avg reward: 970.08614
# eval avg ep len: 1000.00000
# eval d4rl score: 10.07046
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:21:48
# num of updates: 4000
# action loss: 0.10090
# eval avg reward: 1281.25519
# eval avg ep len: 1000.00000
# eval d4rl score: 12.57682
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:22:22
# num of updates: 4100
# action loss: 0.09979
# eval avg reward: 1014.50524
# eval avg ep len: 1000.00000
# eval d4rl score: 10.42824
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:22:54
# num of updates: 4200
# action loss: 0.09824
# eval avg reward: 571.81225
# eval avg ep len: 1000.00000
# eval d4rl score: 6.86250
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:23:26
# num of updates: 4300
# action loss: 0.09482
# eval avg reward: 1139.92944
# eval avg ep len: 1000.00000
# eval d4rl score: 11.43849
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:23:59
# num of updates: 4400
# action loss: 0.09403
# eval avg reward: 1380.68367
# eval avg ep len: 1000.00000
# eval d4rl score: 13.37768
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:24:31
# num of updates: 4500
# action loss: 0.09145
# eval avg reward: 986.30009
# eval avg ep len: 1000.00000
# eval d4rl score: 10.20105
# max d4rl score: 18.33505
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:25:03
# num of updates: 4600
# action loss: 0.08938
# eval avg reward: 2049.10912
# eval avg ep len: 1000.00000
# eval d4rl score: 18.76161
# max d4rl score: 18.33505
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:25:36
# num of updates: 4700
# action loss: 0.08802
# eval avg reward: 2380.01350
# eval avg ep len: 1000.00000
# eval d4rl score: 21.42694
# max d4rl score: 18.76161
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:26:09
# num of updates: 4800
# action loss: 0.08741
# eval avg reward: 1428.99189
# eval avg ep len: 1000.00000
# eval d4rl score: 13.76678
# max d4rl score: 21.42694
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:26:42
# num of updates: 4900
# action loss: 0.08554
# eval avg reward: 2765.20807
# eval avg ep len: 1000.00000
# eval d4rl score: 24.52955
# max d4rl score: 21.42694
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:27:14
# num of updates: 5000
# action loss: 0.08346
# eval avg reward: 3210.76454
# eval avg ep len: 1000.00000
# eval d4rl score: 28.11835
# max d4rl score: 24.52955
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:27:47
# num of updates: 5100
# action loss: 0.08114
# eval avg reward: 2421.93190
# eval avg ep len: 1000.00000
# eval d4rl score: 21.76457
# max d4rl score: 28.11835
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:28:19
# num of updates: 5200
# action loss: 0.08146
# eval avg reward: 2827.60663
# eval avg ep len: 1000.00000
# eval d4rl score: 25.03214
# max d4rl score: 28.11835
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:28:52
# num of updates: 5300
# action loss: 0.07960
# eval avg reward: 2135.93561
# eval avg ep len: 1000.00000
# eval d4rl score: 19.46097
# max d4rl score: 28.11835
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:29:24
# num of updates: 5400
# action loss: 0.07867
# eval avg reward: 3819.98659
# eval avg ep len: 1000.00000
# eval d4rl score: 33.02542
# max d4rl score: 28.11835
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:29:57
# num of updates: 5500
# action loss: 0.07701
# eval avg reward: 3195.29114
# eval avg ep len: 1000.00000
# eval d4rl score: 27.99372
# max d4rl score: 33.02542
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:30:29
# num of updates: 5600
# action loss: 0.07577
# eval avg reward: 3566.63877
# eval avg ep len: 1000.00000
# eval d4rl score: 30.98479
# max d4rl score: 33.02542
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:31:01
# num of updates: 5700
# action loss: 0.07425
# eval avg reward: 3177.10186
# eval avg ep len: 1000.00000
# eval d4rl score: 27.84721
# max d4rl score: 33.02542
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:31:34
# num of updates: 5800
# action loss: 0.07294
# eval avg reward: 3266.02002
# eval avg ep len: 1000.00000
# eval d4rl score: 28.56341
# max d4rl score: 33.02542
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:32:06
# num of updates: 5900
# action loss: 0.07247
# eval avg reward: 2899.12682
# eval avg ep len: 1000.00000
# eval d4rl score: 25.60822
# max d4rl score: 33.02542
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:32:39
# num of updates: 6000
# action loss: 0.07143
# eval avg reward: 3899.91034
# eval avg ep len: 1000.00000
# eval d4rl score: 33.66918
# max d4rl score: 33.02542
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:33:10
# num of updates: 6100
# action loss: 0.07006
# eval avg reward: 3854.93001
# eval avg ep len: 1000.00000
# eval d4rl score: 33.30688
# max d4rl score: 33.66918
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:33:43
# num of updates: 6200
# action loss: 0.06881
# eval avg reward: 3684.11063
# eval avg ep len: 1000.00000
# eval d4rl score: 31.93099
# max d4rl score: 33.66918
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:34:15
# num of updates: 6300
# action loss: 0.06829
# eval avg reward: 3565.22756
# eval avg ep len: 1000.00000
# eval d4rl score: 30.97343
# max d4rl score: 33.66918
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:34:47
# num of updates: 6400
# action loss: 0.06697
# eval avg reward: 3686.30178
# eval avg ep len: 1000.00000
# eval d4rl score: 31.94864
# max d4rl score: 33.66918
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:35:19
# num of updates: 6500
# action loss: 0.06716
# eval avg reward: 4122.53488
# eval avg ep len: 1000.00000
# eval d4rl score: 35.46235
# max d4rl score: 33.66918
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:35:52
# num of updates: 6600
# action loss: 0.06709
# eval avg reward: 3782.72547
# eval avg ep len: 1000.00000
# eval d4rl score: 32.72530
# max d4rl score: 35.46235
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:36:25
# num of updates: 6700
# action loss: 0.06430
# eval avg reward: 3912.70142
# eval avg ep len: 1000.00000
# eval d4rl score: 33.77221
# max d4rl score: 35.46235
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:36:57
# num of updates: 6800
# action loss: 0.06398
# eval avg reward: 4214.57290
# eval avg ep len: 1000.00000
# eval d4rl score: 36.20368
# max d4rl score: 35.46235
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:37:29
# num of updates: 6900
# action loss: 0.06297
# eval avg reward: 4009.65757
# eval avg ep len: 1000.00000
# eval d4rl score: 34.55316
# max d4rl score: 36.20368
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:38:03
# num of updates: 7000
# action loss: 0.06257
# eval avg reward: 3973.61973
# eval avg ep len: 1000.00000
# eval d4rl score: 34.26289
# max d4rl score: 36.20368
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:38:35
# num of updates: 7100
# action loss: 0.06229
# eval avg reward: 4456.81838
# eval avg ep len: 1000.00000
# eval d4rl score: 38.15489
# max d4rl score: 36.20368
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:39:06
# num of updates: 7200
# action loss: 0.06061
# eval avg reward: 4892.54628
# eval avg ep len: 1000.00000
# eval d4rl score: 41.66452
# max d4rl score: 38.15489
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:39:39
# num of updates: 7300
# action loss: 0.06118
# eval avg reward: 4609.82426
# eval avg ep len: 1000.00000
# eval d4rl score: 39.38730
# max d4rl score: 41.66452
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:40:11
# num of updates: 7400
# action loss: 0.05979
# eval avg reward: 4735.52256
# eval avg ep len: 1000.00000
# eval d4rl score: 40.39975
# max d4rl score: 41.66452
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:40:43
# num of updates: 7500
# action loss: 0.05922
# eval avg reward: 3815.22573
# eval avg ep len: 1000.00000
# eval d4rl score: 32.98708
# max d4rl score: 41.66452
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:41:16
# num of updates: 7600
# action loss: 0.05857
# eval avg reward: 4966.82463
# eval avg ep len: 1000.00000
# eval d4rl score: 42.26281
# max d4rl score: 41.66452
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:41:48
# num of updates: 7700
# action loss: 0.05806
# eval avg reward: 4509.35796
# eval avg ep len: 1000.00000
# eval d4rl score: 38.57807
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:42:21
# num of updates: 7800
# action loss: 0.05752
# eval avg reward: 4322.93096
# eval avg ep len: 1000.00000
# eval d4rl score: 37.07647
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:42:53
# num of updates: 7900
# action loss: 0.05732
# eval avg reward: 4354.38904
# eval avg ep len: 1000.00000
# eval d4rl score: 37.32985
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:43:26
# num of updates: 8000
# action loss: 0.05620
# eval avg reward: 4836.06443
# eval avg ep len: 1000.00000
# eval d4rl score: 41.20958
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:43:58
# num of updates: 8100
# action loss: 0.05583
# eval avg reward: 4574.19495
# eval avg ep len: 1000.00000
# eval d4rl score: 39.10031
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:44:31
# num of updates: 8200
# action loss: 0.05642
# eval avg reward: 4360.48319
# eval avg ep len: 1000.00000
# eval d4rl score: 37.37894
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:45:03
# num of updates: 8300
# action loss: 0.05480
# eval avg reward: 4455.86308
# eval avg ep len: 1000.00000
# eval d4rl score: 38.14719
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:45:35
# num of updates: 8400
# action loss: 0.05412
# eval avg reward: 4561.16544
# eval avg ep len: 1000.00000
# eval d4rl score: 38.99537
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:46:08
# num of updates: 8500
# action loss: 0.05390
# eval avg reward: 4587.39980
# eval avg ep len: 1000.00000
# eval d4rl score: 39.20667
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:46:40
# num of updates: 8600
# action loss: 0.05373
# eval avg reward: 4573.35725
# eval avg ep len: 1000.00000
# eval d4rl score: 39.09357
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:47:12
# num of updates: 8700
# action loss: 0.05320
# eval avg reward: 4886.64066
# eval avg ep len: 1000.00000
# eval d4rl score: 41.61696
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:47:45
# num of updates: 8800
# action loss: 0.05280
# eval avg reward: 4847.30718
# eval avg ep len: 1000.00000
# eval d4rl score: 41.30014
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:48:17
# num of updates: 8900
# action loss: 0.05278
# eval avg reward: 4936.64881
# eval avg ep len: 1000.00000
# eval d4rl score: 42.01975
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:48:49
# num of updates: 9000
# action loss: 0.05155
# eval avg reward: 4907.71604
# eval avg ep len: 1000.00000
# eval d4rl score: 41.78671
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:49:21
# num of updates: 9100
# action loss: 0.05195
# eval avg reward: 4874.19884
# eval avg ep len: 1000.00000
# eval d4rl score: 41.51674
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:49:54
# num of updates: 9200
# action loss: 0.05166
# eval avg reward: 4850.02200
# eval avg ep len: 1000.00000
# eval d4rl score: 41.32201
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:50:26
# num of updates: 9300
# action loss: 0.05006
# eval avg reward: 4560.24589
# eval avg ep len: 1000.00000
# eval d4rl score: 38.98796
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:50:59
# num of updates: 9400
# action loss: 0.05021
# eval avg reward: 4722.61633
# eval avg ep len: 1000.00000
# eval d4rl score: 40.29580
# max d4rl score: 42.26281
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:51:31
# num of updates: 9500
# action loss: 0.04966
# eval avg reward: 4971.59391
# eval avg ep len: 1000.00000
# eval d4rl score: 42.30123
# max d4rl score: 42.26281
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:52:03
# num of updates: 9600
# action loss: 0.04969
# eval avg reward: 4483.58345
# eval avg ep len: 1000.00000
# eval d4rl score: 38.37047
# max d4rl score: 42.30123
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:52:35
# num of updates: 9700
# action loss: 0.04903
# eval avg reward: 4854.76457
# eval avg ep len: 1000.00000
# eval d4rl score: 41.36021
# max d4rl score: 42.30123
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:53:07
# num of updates: 9800
# action loss: 0.04847
# eval avg reward: 4990.45070
# eval avg ep len: 1000.00000
# eval d4rl score: 42.45311
# max d4rl score: 42.30123
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:53:39
# num of updates: 9900
# action loss: 0.04765
# eval avg reward: 4770.72516
# eval avg ep len: 1000.00000
# eval d4rl score: 40.68330
# max d4rl score: 42.45311
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:54:11
# num of updates: 10000
# action loss: 0.04848
# eval avg reward: 4967.51816
# eval avg ep len: 1000.00000
# eval d4rl score: 42.26840
# max d4rl score: 42.45311
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:54:44
# num of updates: 10100
# action loss: 0.04796
# eval avg reward: 4898.88894
# eval avg ep len: 1000.00000
# eval d4rl score: 41.71561
# max d4rl score: 42.45311
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:55:16
# num of updates: 10200
# action loss: 0.04678
# eval avg reward: 4930.71765
# eval avg ep len: 1000.00000
# eval d4rl score: 41.97198
# max d4rl score: 42.45311
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:55:49
# num of updates: 10300
# action loss: 0.04674
# eval avg reward: 4925.53458
# eval avg ep len: 1000.00000
# eval d4rl score: 41.93023
# max d4rl score: 42.45311
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:56:21
# num of updates: 10400
# action loss: 0.04665
# eval avg reward: 5009.09441
# eval avg ep len: 1000.00000
# eval d4rl score: 42.60328
# max d4rl score: 42.45311
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:56:54
# num of updates: 10500
# action loss: 0.04664
# eval avg reward: 4786.74301
# eval avg ep len: 1000.00000
# eval d4rl score: 40.81232
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:57:26
# num of updates: 10600
# action loss: 0.04564
# eval avg reward: 4998.62242
# eval avg ep len: 1000.00000
# eval d4rl score: 42.51893
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:57:58
# num of updates: 10700
# action loss: 0.04578
# eval avg reward: 4914.92201
# eval avg ep len: 1000.00000
# eval d4rl score: 41.84475
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:58:30
# num of updates: 10800
# action loss: 0.04579
# eval avg reward: 4489.87445
# eval avg ep len: 1000.00000
# eval d4rl score: 38.42114
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:59:02
# num of updates: 10900
# action loss: 0.04481
# eval avg reward: 4728.41305
# eval avg ep len: 1000.00000
# eval d4rl score: 40.34249
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 0:59:35
# num of updates: 11000
# action loss: 0.04523
# eval avg reward: 4540.44823
# eval avg ep len: 1000.00000
# eval d4rl score: 38.82850
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:00:07
# num of updates: 11100
# action loss: 0.04521
# eval avg reward: 4972.36283
# eval avg ep len: 1000.00000
# eval d4rl score: 42.30742
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:00:39
# num of updates: 11200
# action loss: 0.04472
# eval avg reward: 4465.10775
# eval avg ep len: 1000.00000
# eval d4rl score: 38.22165
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:01:12
# num of updates: 11300
# action loss: 0.04457
# eval avg reward: 4488.48220
# eval avg ep len: 1000.00000
# eval d4rl score: 38.40993
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:01:43
# num of updates: 11400
# action loss: 0.04484
# eval avg reward: 4929.65013
# eval avg ep len: 1000.00000
# eval d4rl score: 41.96338
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:02:15
# num of updates: 11500
# action loss: 0.04395
# eval avg reward: 4988.21582
# eval avg ep len: 1000.00000
# eval d4rl score: 42.43511
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:02:47
# num of updates: 11600
# action loss: 0.04360
# eval avg reward: 4904.08776
# eval avg ep len: 1000.00000
# eval d4rl score: 41.75749
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:03:19
# num of updates: 11700
# action loss: 0.04266
# eval avg reward: 4939.64492
# eval avg ep len: 1000.00000
# eval d4rl score: 42.04389
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:03:50
# num of updates: 11800
# action loss: 0.04376
# eval avg reward: 4962.35374
# eval avg ep len: 1000.00000
# eval d4rl score: 42.22680
# max d4rl score: 42.60328
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:04:23
# num of updates: 11900
# action loss: 0.04288
# eval avg reward: 5012.30414
# eval avg ep len: 1000.00000
# eval d4rl score: 42.62913
# max d4rl score: 42.60328
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:04:55
# num of updates: 12000
# action loss: 0.04279
# eval avg reward: 4964.85350
# eval avg ep len: 1000.00000
# eval d4rl score: 42.24693
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:05:28
# num of updates: 12100
# action loss: 0.04320
# eval avg reward: 4548.32540
# eval avg ep len: 1000.00000
# eval d4rl score: 38.89194
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:06:00
# num of updates: 12200
# action loss: 0.04240
# eval avg reward: 4981.07150
# eval avg ep len: 1000.00000
# eval d4rl score: 42.37756
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:06:33
# num of updates: 12300
# action loss: 0.04243
# eval avg reward: 4990.98281
# eval avg ep len: 1000.00000
# eval d4rl score: 42.45740
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:07:05
# num of updates: 12400
# action loss: 0.04202
# eval avg reward: 4986.56532
# eval avg ep len: 1000.00000
# eval d4rl score: 42.42182
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:07:37
# num of updates: 12500
# action loss: 0.04207
# eval avg reward: 4978.91381
# eval avg ep len: 1000.00000
# eval d4rl score: 42.36018
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:08:09
# num of updates: 12600
# action loss: 0.04223
# eval avg reward: 4625.04160
# eval avg ep len: 1000.00000
# eval d4rl score: 39.50987
# max d4rl score: 42.62913
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:08:42
# num of updates: 12700
# action loss: 0.04232
# eval avg reward: 5044.26568
# eval avg ep len: 1000.00000
# eval d4rl score: 42.88657
# max d4rl score: 42.62913
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:09:13
# num of updates: 12800
# action loss: 0.04166
# eval avg reward: 4714.88432
# eval avg ep len: 1000.00000
# eval d4rl score: 40.23352
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:09:46
# num of updates: 12900
# action loss: 0.04156
# eval avg reward: 4959.23493
# eval avg ep len: 1000.00000
# eval d4rl score: 42.20168
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:10:19
# num of updates: 13000
# action loss: 0.04116
# eval avg reward: 4927.88814
# eval avg ep len: 1000.00000
# eval d4rl score: 41.94919
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:10:52
# num of updates: 13100
# action loss: 0.04057
# eval avg reward: 4991.87047
# eval avg ep len: 1000.00000
# eval d4rl score: 42.46455
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:11:24
# num of updates: 13200
# action loss: 0.04094
# eval avg reward: 5030.67562
# eval avg ep len: 1000.00000
# eval d4rl score: 42.77711
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:11:56
# num of updates: 13300
# action loss: 0.04071
# eval avg reward: 4760.89053
# eval avg ep len: 1000.00000
# eval d4rl score: 40.60408
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:12:28
# num of updates: 13400
# action loss: 0.04038
# eval avg reward: 5006.96560
# eval avg ep len: 1000.00000
# eval d4rl score: 42.58613
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:13:00
# num of updates: 13500
# action loss: 0.04019
# eval avg reward: 3726.53061
# eval avg ep len: 1000.00000
# eval d4rl score: 32.27267
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:13:32
# num of updates: 13600
# action loss: 0.04077
# eval avg reward: 4270.84476
# eval avg ep len: 1000.00000
# eval d4rl score: 36.65693
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:14:05
# num of updates: 13700
# action loss: 0.04087
# eval avg reward: 4990.16567
# eval avg ep len: 1000.00000
# eval d4rl score: 42.45081
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:14:38
# num of updates: 13800
# action loss: 0.04015
# eval avg reward: 4472.53082
# eval avg ep len: 1000.00000
# eval d4rl score: 38.28144
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:15:10
# num of updates: 13900
# action loss: 0.04004
# eval avg reward: 4851.77291
# eval avg ep len: 1000.00000
# eval d4rl score: 41.33611
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:15:42
# num of updates: 14000
# action loss: 0.03969
# eval avg reward: 4956.37089
# eval avg ep len: 1000.00000
# eval d4rl score: 42.17861
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:16:14
# num of updates: 14100
# action loss: 0.03917
# eval avg reward: 4900.73483
# eval avg ep len: 1000.00000
# eval d4rl score: 41.73048
# max d4rl score: 42.88657
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:16:46
# num of updates: 14200
# action loss: 0.03942
# ...
# ============================================================
# time elapsed: 1:22:39
# num of updates: 15300
# action loss: 0.03799
# eval avg reward: 5055.64756
# eval avg ep len: 1000.00000
# eval d4rl score: 42.97825
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:23:11
# num of updates: 15400
# action loss: 0.03819
# eval avg reward: 4959.08407
# eval avg ep len: 1000.00000
# eval d4rl score: 42.20046
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:23:44
# num of updates: 15500
# action loss: 0.03779
# eval avg reward: 4700.27256
# eval avg ep len: 1000.00000
# eval d4rl score: 40.11583
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:24:16
# num of updates: 15600
# action loss: 0.03824
# eval avg reward: 4964.77791
# eval avg ep len: 1000.00000
# eval d4rl score: 42.24633
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:24:48
# num of updates: 15700
# action loss: 0.03797
# eval avg reward: 4918.85036
# eval avg ep len: 1000.00000
# eval d4rl score: 41.87639
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:25:21
# num of updates: 15800
# action loss: 0.03883
# eval avg reward: 4654.88057
# eval avg ep len: 1000.00000
# eval d4rl score: 39.75021
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:25:53
# num of updates: 15900
# action loss: 0.03818
# eval avg reward: 4572.24663
# eval avg ep len: 1000.00000
# eval d4rl score: 39.08462
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:26:25
# num of updates: 16000
# action loss: 0.03762
# eval avg reward: 4972.21358
# eval avg ep len: 1000.00000
# eval d4rl score: 42.30622
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:26:58
# num of updates: 16100
# action loss: 0.03763
# eval avg reward: 4971.97831
# eval avg ep len: 1000.00000
# eval d4rl score: 42.30432
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:27:30
# num of updates: 16200
# action loss: 0.03707
# eval avg reward: 5005.36842
# eval avg ep len: 1000.00000
# eval d4rl score: 42.57327
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:28:02
# num of updates: 16300
# action loss: 0.03851
# eval avg reward: 5052.79282
# eval avg ep len: 1000.00000
# eval d4rl score: 42.95525
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:28:34
# num of updates: 16400
# action loss: 0.03737
# eval avg reward: 4903.95443
# eval avg ep len: 1000.00000
# eval d4rl score: 41.75641
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:29:07
# num of updates: 16500
# action loss: 0.03731
# eval avg reward: 4939.81827
# eval avg ep len: 1000.00000
# eval d4rl score: 42.04528
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:29:39
# num of updates: 16600
# action loss: 0.03727
# eval avg reward: 4948.74412
# eval avg ep len: 1000.00000
# eval d4rl score: 42.11718
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:30:12
# num of updates: 16700
# action loss: 0.03729
# eval avg reward: 4980.58255
# eval avg ep len: 1000.00000
# eval d4rl score: 42.37363
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:30:44
# num of updates: 16800
# action loss: 0.03686
# eval avg reward: 4948.10781
# eval avg ep len: 1000.00000
# eval d4rl score: 42.11205
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:31:17
# num of updates: 16900
# action loss: 0.03683
# eval avg reward: 5016.67949
# eval avg ep len: 1000.00000
# eval d4rl score: 42.66437
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:31:49
# num of updates: 17000
# action loss: 0.03685
# eval avg reward: 5006.40409
# eval avg ep len: 1000.00000
# eval d4rl score: 42.58161
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:32:22
# num of updates: 17100
# action loss: 0.03685
# eval avg reward: 4992.26066
# eval avg ep len: 1000.00000
# eval d4rl score: 42.46769
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:32:54
# num of updates: 17200
# action loss: 0.03672
# eval avg reward: 4423.62758
# eval avg ep len: 1000.00000
# eval d4rl score: 37.88755
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:33:27
# num of updates: 17300
# action loss: 0.03672
# eval avg reward: 4939.53152
# eval avg ep len: 1000.00000
# eval d4rl score: 42.04297
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:34:00
# num of updates: 17400
# action loss: 0.03658
# eval avg reward: 5068.44480
# eval avg ep len: 1000.00000
# eval d4rl score: 43.08133
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:34:33
# num of updates: 17500
# action loss: 0.03671
# eval avg reward: 5016.76540
# eval avg ep len: 1000.00000
# eval d4rl score: 42.66507
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:35:06
# num of updates: 17600
# action loss: 0.03656
# eval avg reward: 5010.79336
# eval avg ep len: 1000.00000
# eval d4rl score: 42.61696
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:35:39
# num of updates: 17700
# action loss: 0.03706
# eval avg reward: 4983.54144
# eval avg ep len: 1000.00000
# eval d4rl score: 42.39746
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:36:11
# num of updates: 17800
# action loss: 0.03618
# eval avg reward: 5009.05761
# eval avg ep len: 1000.00000
# eval d4rl score: 42.60298
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:36:44
# num of updates: 17900
# action loss: 0.03626
# eval avg reward: 5064.83012
# eval avg ep len: 1000.00000
# eval d4rl score: 43.05221
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:37:17
# num of updates: 18000
# action loss: 0.03637
# eval avg reward: 4965.92103
# eval avg ep len: 1000.00000
# eval d4rl score: 42.25553
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:37:49
# num of updates: 18100
# action loss: 0.03622
# eval avg reward: 4992.80858
# eval avg ep len: 1000.00000
# eval d4rl score: 42.47210
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:38:21
# num of updates: 18200
# action loss: 0.03586
# eval avg reward: 4997.41666
# eval avg ep len: 1000.00000
# eval d4rl score: 42.50922
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:38:53
# num of updates: 18300
# action loss: 0.03590
# eval avg reward: 4938.57436
# eval avg ep len: 1000.00000
# eval d4rl score: 42.03526
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:39:26
# num of updates: 18400
# action loss: 0.03586
# eval avg reward: 5005.44152
# eval avg ep len: 1000.00000
# eval d4rl score: 42.57386
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:39:58
# num of updates: 18500
# action loss: 0.03543
# eval avg reward: 4782.84920
# eval avg ep len: 1000.00000
# eval d4rl score: 40.78095
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:40:30
# num of updates: 18600
# action loss: 0.03561
# eval avg reward: 5004.73835
# eval avg ep len: 1000.00000
# eval d4rl score: 42.56819
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:41:03
# num of updates: 18700
# action loss: 0.03564
# eval avg reward: 4987.98654
# eval avg ep len: 1000.00000
# eval d4rl score: 42.43326
# max d4rl score: 43.18487
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:41:35
# num of updates: 18800
# action loss: 0.03579
# eval avg reward: 5086.87595
# eval avg ep len: 1000.00000
# eval d4rl score: 43.22978
# max d4rl score: 43.18487
# saving max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:42:07
# num of updates: 18900
# action loss: 0.03521
# eval avg reward: 5021.60511
# eval avg ep len: 1000.00000
# eval d4rl score: 42.70405
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:42:40
# num of updates: 19000
# action loss: 0.03565
# eval avg reward: 4916.78398
# eval avg ep len: 1000.00000
# eval d4rl score: 41.85975
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:43:12
# num of updates: 19100
# action loss: 0.03531
# eval avg reward: 5009.24777
# eval avg ep len: 1000.00000
# eval d4rl score: 42.60451
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:43:45
# num of updates: 19200
# action loss: 0.03558
# eval avg reward: 5010.46355
# eval avg ep len: 1000.00000
# eval d4rl score: 42.61431
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:44:17
# num of updates: 19300
# action loss: 0.03546
# eval avg reward: 4988.50872
# eval avg ep len: 1000.00000
# eval d4rl score: 42.43747
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:44:50
# num of updates: 19400
# action loss: 0.03591
# eval avg reward: 5065.16596
# eval avg ep len: 1000.00000
# eval d4rl score: 43.05492
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:45:23
# num of updates: 19500
# action loss: 0.03572
# eval avg reward: 5060.22966
# eval avg ep len: 1000.00000
# eval d4rl score: 43.01516
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:45:55
# num of updates: 19600
# action loss: 0.03488
# eval avg reward: 4985.78961
# eval avg ep len: 1000.00000
# eval d4rl score: 42.41557
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:46:28
# num of updates: 19700
# action loss: 0.03528
# eval avg reward: 4898.36046
# eval avg ep len: 1000.00000
# eval d4rl score: 41.71136
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:47:00
# num of updates: 19800
# action loss: 0.03535
# eval avg reward: 5026.50370
# eval avg ep len: 1000.00000
# eval d4rl score: 42.74351
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:47:33
# num of updates: 19900
# action loss: 0.03481
# eval avg reward: 4750.18599
# eval avg ep len: 1000.00000
# eval d4rl score: 40.51786
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# time elapsed: 1:48:05
# num of updates: 20000
# action loss: 0.03483
# eval avg reward: 4916.50226
# eval avg ep len: 1000.00000
# eval d4rl score: 41.85748
# max d4rl score: 43.22978
# saving current model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================
# finished training!
# ============================================================
# started training at: 24-04-04-10-52-44
# finished training at: 24-04-04-12-40-49
# total training time: 1:48:05
# max d4rl score: 43.22978
# saved max d4rl score model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# saved last updated model at: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44.pt
# ============================================================

# %% [markdown]
# # Test

# %%
eval_dataset = "medium"		# medium / medium-replay / medium-expert
eval_rtg_scale = 1000		# normalize returns to go

# eval_env_name = "Walker2d-v3"
# eval_rtg_target = 5000
# eval_env_d4rl_name = f'walker2d-{eval_dataset}-v2'

eval_env_name = "HalfCheetah-v3"
eval_rtg_target = 6000
eval_env_d4rl_name = f'halfcheetah-{eval_dataset}-v2'

# eval_env_name = "Hopper-v3"
# eval_rtg_target = 3600
# eval_env_d4rl_name = f'hopper-{eval_dataset}-v2'


num_test_eval_ep = 10			# num of evaluation episodes
eval_max_eval_ep_len = 1000		# max len of one episode


context_len = 20        # K in decision transformer
n_blocks = 3            # num of transformer blocks
embed_dim = 128         # embedding (hidden) dim of transformer
n_heads = 1             # num of transformer heads
dropout_p = 0.1         # dropout probability


eval_chk_pt_dir = "./dt_runs/"


# TODO: choose model to eval

# walker
# eval_chk_pt_name = "dt_walker2d-medium-v2_model_22-02-22-09-24-12_best.pt"  # original
# eval_chk_pt_name = "dt_walker2d-medium-v2_model_23-06-07-14-04-28_best.pt"  # custom

# cheetah
# eval_chk_pt_name = "dt_halfcheetah-medium-v2_model_22-02-13-09-03-10_best.pt"  # original
eval_chk_pt_name = "dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt"  # custom

eval_chk_pt_list = [eval_chk_pt_name]


## manually override check point list
## passing a list will evaluate on all checkpoints
## and output mean and std score


# eval_chk_pt_list = [
# 	"dt_walker2d-medium-v2_model_22-02-20-06-27-12_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-20-09-11-30_best.pt",
# 	"dt_walker2d-medium-v2_model_22-02-22-09-24-12_best.pt"
# ]



env_data_stats = get_d4rl_dataset_stats(eval_env_d4rl_name)
eval_state_mean = np.array(env_data_stats['state_mean'])
eval_state_std = np.array(env_data_stats['state_std'])

eval_env = gym.make(eval_env_name)

state_dim = eval_env.observation_space.shape[0]
act_dim = eval_env.action_space.shape[0]

all_scores = []

for eval_chk_pt_name in eval_chk_pt_list:

	eval_model = DecisionTransformer(
				state_dim=state_dim,
				act_dim=act_dim,
				n_blocks=n_blocks,
				h_dim=embed_dim,
				context_len=context_len,
				n_heads=n_heads,
				drop_p=dropout_p,
			).to(device)


	eval_chk_pt_path = os.path.join(eval_chk_pt_dir, eval_chk_pt_name)

	# load checkpoint
	eval_model.load_state_dict(torch.load(eval_chk_pt_path, map_location=device))

	print("model loaded from: " + eval_chk_pt_path)

	# evaluate on env
	results = evaluate_on_env(eval_model, device, context_len,
							eval_env, eval_rtg_target, eval_rtg_scale,
							num_test_eval_ep, eval_max_eval_ep_len,
							eval_state_mean, eval_state_std)
	print(results)

	norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
	print("normalized d4rl score: ", norm_score)

	all_scores.append(norm_score)

print("=" * 60)
all_scores = np.array(all_scores)
print("evaluated on env: " + eval_env_name)
print("total num of checkpoints evaluated: " + str(len(eval_chk_pt_list)))
print("d4rl score mean: " + format(all_scores.mean(), ".5f"))
print("d4rl score std: " + format(all_scores.std(), ".5f"))
print("d4rl score var: " + format(all_scores.var(), ".5f"))
print("=" * 60)
# Out:
# model loaded from: ./dt_runs/dt_halfcheetah-medium-v2_model_24-04-04-10-52-44_best.pt
# {'eval/avg_reward': 5081.695573782263, 'eval/avg_ep_len': 1000.0}
# normalized d4rl score:  43.18805670929633
# ============================================================
# evaluated on env: HalfCheetah-v3
# total num of checkpoints evaluated: 1
# d4rl score mean: 43.18806
# d4rl score std: 0.00000
# d4rl score var: 0.00000
# ============================================================

# %% [markdown]
# # Render env
#
#
#
# *   saves mp4 video of env frames and plays it in notebook

# %%
from gym.wrappers import RecordVideo

num_test_eval_ep = 1
eval_max_ep_len = 1000


directory = "./render_video"
eval_env = gym.make(eval_env_name)
eval_env = RecordVideo(eval_env, directory)

results = evaluate_on_env(eval_model, device, context_len,
                        eval_env, eval_rtg_target, eval_rtg_scale,
                        num_test_eval_ep, eval_max_ep_len,
						eval_state_mean, eval_state_std)
print(results)

norm_score = get_d4rl_normalized_score(results['eval/avg_reward'], eval_env_name) * 100
print("normalized d4rl score: ", norm_score)

eval_env.close()

# %%
import glob
import io
import base64
from IPython import display as ipythondisplay
from IPython.display import HTML
from IPython.display import clear_output
from time import sleep
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

def show_video(folder="./render_video"):
    mp4list = glob.glob(folder + '/*.mp4')
    if len(mp4list) > 0:
        mp4 = sorted(mp4list, key=lambda x: x[-15:], reverse=True)[0]
        video = io.open(mp4, 'r+b').read()
        encoded = base64.b64encode(video)
        ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
    else:
        print("Could not find video")

# %%
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %% [markdown]
# # plots

# %%
import numpy as np
import pickle

import pandas as pd
import glob

import matplotlib.pyplot as plt


env_d4rl_name = 'halfcheetah-medium-v2'

log_dir = 'dt_runs/'

x_key = "num_updates"
y_key = "eval_d4rl_score"
y_smoothing_win = 5
plot_avg = False
save_fig = False

if plot_avg:
    save_fig_path = env_d4rl_name + "_avg.png"
else:
    save_fig_path = env_d4rl_name + ".png"


all_files = glob.glob(log_dir + f'/dt_{env_d4rl_name}*.csv')

ax = plt.gca()
ax.set_title(env_d4rl_name)

if plot_avg:
    name_list = []
    df_list = []
    for filename in all_files:
        frame = pd.read_csv(filename, index_col=None, header=0)
        print(filename, frame.shape)
        frame['y_smooth'] = frame[y_key].rolling(window=y_smoothing_win).mean()
        df_list.append(frame)


    df_concat = pd.concat(df_list)
    df_concat_groupby = df_concat.groupby(df_concat.index)
    data_avg = df_concat_groupby.mean()

    data_avg.plot(x=x_key, y='y_smooth', ax=ax)

    ax.set_xlabel(x_key)
    ax.set_ylabel(y_key)
    ax.legend(['avg of all runs'], loc='lower right')

    if save_fig:
        plt.savefig(save_fig_path)

    plt.show()


else:
    name_list = []
    for filename in all_files:
        frame = pd.read_csv(filename, index_col=None, header=0)
        print(filename, frame.shape)
        frame['y_smooth'] = frame[y_key].rolling(window=y_smoothing_win).mean()
        frame.plot(x=x_key, y='y_smooth', ax=ax)
        name_list.append(filename.split('/')[-1])

    ax.set_xlabel(x_key)
    ax.set_ylabel(y_key)
    ax.legend(name_list, loc='lower right')

    if save_fig:
        plt.savefig(save_fig_path)

    plt.show()
# Out:
# dt_runs/dt_halfcheetah-medium-v2_log_23-12-11-13-02-17.csv (200, 6)
